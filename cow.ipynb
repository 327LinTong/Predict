# %%
#先導入資料處理會用到的模組
import numpy as np
import numpy.random as random
import scipy as sp
from pandas import Series, DataFrame
import pandas as pd

# 可視化模組
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

# 機器學習模組
import sklearn

# %%
breed=pd.read_csv('breed.csv',sep=',') #配種紀錄
report=pd.read_csv('report.csv',sep=',') #檢測報告
spec=pd.read_csv('spec.csv',sep=',') #健康狀況
birth= pd.read_csv('birth.csv',sep=',') #分娩資料
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
test = report[report['11'].isna()]
test
# Out:
#            1     2  3  4        5           6            7                8  \
# 479      480  2019  1  A    52631    501H9952     97040152  2011/3/17 00:00
# 741      742  2019  2  A    52640    501H9952     96040567   2011/4/1 00:00
# 742      743  2019  3  A    52640    501H9952     96040567   2011/4/1 00:00
# 743      744  2019  4  A    52640    501H9952     96040567   2011/4/1 00:00
# 744      745  2019  5  A    52640    501H9952     96040567   2011/4/1 00:00
# ...      ...   ... .. ..      ...         ...          ...              ...
# 37480  37481  2019  6  C  6187446  001HO11511  4.17046e+06   2017/6/1 00:00
# 37481  37482  2019  6  C  6187448  001HO11511  3.17231e+06  2017/6/17 00:00
# 37482  37483  2019  6  C  6187449  001HO11511  2.17684e+06  2017/8/10 00:00
# 37483  37484  2019  7  C  6187449  001HO11511  2.17684e+06  2017/8/10 00:00
# 37484  37485  2019  7  C  6187451  001HO11511  2.17682e+06  2017/8/21 00:00
#
#        9     10  ...               12               13  14               15  \
# 479    4  435.0  ...  2017/11/1 00:00  2019/1/10 00:00  94  2019/1/15 00:00
# 741    4   13.0  ...  2019/1/29 00:00  2019/2/11 00:00  94  2019/2/12 00:00
# 742    4   35.0  ...  2019/1/29 00:00   2019/3/5 00:00  95   2019/3/6 00:00
# 743    4   70.0  ...  2019/1/29 00:00   2019/4/9 00:00  96  2019/4/11 00:00
# 744    4   98.0  ...  2019/1/29 00:00   2019/5/7 00:00  97   2019/5/9 00:00
# ...   ..    ...  ...              ...              ...  ..              ...
# 37480  1   15.0  ...  2019/6/10 00:00  2019/6/25 00:00  24  2019/6/27 00:00
# 37481  1   22.0  ...   2019/6/3 00:00  2019/6/25 00:00  24  2019/6/27 00:00
# 37482  1   21.0  ...   2019/6/4 00:00  2019/6/25 00:00  22  2019/6/27 00:00
# 37483  1   51.0  ...   2019/6/4 00:00  2019/7/25 00:00  23  2019/7/26 00:00
# 37484  1   15.0  ...  2019/7/10 00:00  2019/7/25 00:00  23  2019/7/26 00:00
#
#                     16          17 18               19               20  \
# 479     2019/2/3 00:00  551HO00657  6   2016/8/4 00:00   2018/1/6 00:00
# 741    2019/2/28 00:00  551HO00695  0  2017/6/17 00:00  2019/2/28 00:00
# 742    2019/2/28 00:00  551HO00695  1  2017/6/17 00:00  2019/2/28 00:00
# 743    2019/2/28 00:00  551HO00695  1  2017/6/17 00:00  2019/2/28 00:00
# 744    2019/2/28 00:00  551HO00695  1  2017/6/17 00:00  2019/2/28 00:00
# ...                ...         ... ..              ...              ...
# 37480  2019/7/24 00:00  001HO12901  0              NaN  2019/7/24 00:00
# 37481              NaN         NaN  0              NaN              NaN
# 37482              NaN         NaN  0              NaN              NaN
# 37483              NaN         NaN  0              NaN              NaN
# 37484              NaN         NaN  0              NaN              NaN
#
#                21
# 479    614HO07276
# 741    551HO00695
# 742    551HO00695
# 743    551HO00695
# 744    551HO00695
# ...           ...
# 37480  001HO12901
# 37481         NaN
# 37482         NaN
# 37483         NaN
# 37484         NaN
#
# [4263 rows x 21 columns]

# %%
report = report[report['11'].notna()]

# %%
new_train=pd.DataFrame(data=report,columns=['1','3','4','5','6','7','9','11','10','14','18','21','season','cycle','times','sub','year','cycle2','health','weight'])
new_test=pd.DataFrame(data=test,columns=['1','3','4','5','6','7','9','11','10','14','18','21','season','cycle','times','sub','year','cycle2','health','weight'])

# %%
new_train
# Out:
#            1  3  4         5         6            7  9    11     10   14  18  \
# 0          1  3  A     52612  507H7173     96040545  1  29.4   78.0   26   1
# 1          2  4  A     52612  507H7173     96040545  1  27.8  107.0   27   1
# 2          3  5  A     52612  507H7173     96040545  1   9.0  140.0   28   2
# 3          4  6  A     52612  507H7173     96040545  1  13.0  175.0   29   2
# 4          5  7  A     52612  507H7173     96040545  1  13.2  210.0   30   2
# ...      ... .. ..       ...       ...          ... ..   ...    ...  ...  ..
# 37512  37513  1  C  93184912   14H1999  8.51715e+07  8  20.0   12.0  130   0
# 37513  37514  5  C  93184912   14H1999  8.51715e+07  8  21.0  137.0  134   0
# 37514  37515  6  C  93184912   14H1999  8.51715e+07  8  19.0  168.0  135   0
# 37515  37516  7  C  93184912   14H1999  8.51715e+07  8  12.0  197.0  136   0
# 37516  37517  8  C  93184912   14H1999  8.51715e+07  8  10.0  229.0  137   0
#
#              21  season  cycle  times  sub  year  cycle2  health  weight
# 0      501H8784     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 1      501H8784     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 2      501H8784     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 3      501H8784     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 4      501H8784     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# ...         ...     ...    ...    ...  ...   ...     ...     ...     ...
# 37512       NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37513       NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37514       NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37515       NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37516       NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
#
# [33254 rows x 20 columns]

# %%
new_test
# Out:
#            1  3  4        5           6            7  9  11     10  14  18  \
# 479      480  1  A    52631    501H9952     97040152  4 NaN  435.0  94   6
# 741      742  2  A    52640    501H9952     96040567  4 NaN   13.0  94   0
# 742      743  3  A    52640    501H9952     96040567  4 NaN   35.0  95   1
# 743      744  4  A    52640    501H9952     96040567  4 NaN   70.0  96   1
# 744      745  5  A    52640    501H9952     96040567  4 NaN   98.0  97   1
# ...      ... .. ..      ...         ...          ... ..  ..    ...  ..  ..
# 37480  37481  6  C  6187446  001HO11511  4.17046e+06  1 NaN   15.0  24   0
# 37481  37482  6  C  6187448  001HO11511  3.17231e+06  1 NaN   22.0  24   0
# 37482  37483  6  C  6187449  001HO11511  2.17684e+06  1 NaN   21.0  22   0
# 37483  37484  7  C  6187449  001HO11511  2.17684e+06  1 NaN   51.0  23   0
# 37484  37485  7  C  6187451  001HO11511  2.17682e+06  1 NaN   15.0  23   0
#
#                21  season  cycle  times  sub  year  cycle2  health  weight
# 479    614HO07276     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 741    551HO00695     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 742    551HO00695     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 743    551HO00695     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 744    551HO00695     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# ...           ...     ...    ...    ...  ...   ...     ...     ...     ...
# 37480  001HO12901     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37481         NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37482         NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37483         NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 37484         NaN     NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
#
# [4263 rows x 20 columns]

# %%
new_train.reset_index(inplace=True)
new_test.reset_index(inplace=True)

# %%
new_train['11']
# Out:
# 0        29.4
# 1        27.8
# 2         9.0
# 3        13.0
# 4        13.2
#          ...
# 33249    20.0
# 33250    21.0
# 33251    19.0
# 33252    12.0
# 33253    10.0
# Name: 11, Length: 33254, dtype: float64

# %%
new_test.isna().sum()
# Out:
# index        0
# 1            0
# 3            0
# 4            0
# 5            0
# 6          247
# 7          329
# 9            0
# 11        4263
# 10           0
# 14           0
# 18           0
# 21         403
# season    4263
# cycle     4263
# times     4263
# sub       4263
# year      4263
# cycle2    4263
# health    4263
# weight    4263
# dtype: int64

# %%
new_train.isna().sum()
# Out:
# index         0
# 1             0
# 3             0
# 4             0
# 5             0
# 6           629
# 7          3255
# 9             0
# 11            0
# 10            1
# 14            0
# 18            0
# 21         1028
# season    33254
# cycle     33254
# times     33254
# sub       33254
# year      33254
# cycle2    33254
# health    33254
# weight    33254
# dtype: int64

# %%
new_train.head(25)
# Out:
#     index   1   3  4      5         6         7  9    11     10  ...  18  \
# 0       0   1   3  A  52612  507H7173  96040545  1  29.4   78.0  ...   1
# 1       1   2   4  A  52612  507H7173  96040545  1  27.8  107.0  ...   1
# 2       2   3   5  A  52612  507H7173  96040545  1   9.0  140.0  ...   2
# 3       3   4   6  A  52612  507H7173  96040545  1  13.0  175.0  ...   2
# 4       4   5   7  A  52612  507H7173  96040545  1  13.2  210.0  ...   2
# 5       5   6   8  A  52612  507H7173  96040545  1  15.7  239.0  ...   2
# 6       6   7  10  A  52612  507H7173  96040545  1  12.8  281.0  ...   3
# 7       7   8  11  A  52612  507H7173  96040545  1   8.8  311.0  ...   3
# 8       8   9  12  A  52612  507H7173  96040545  1   9.0  337.0  ...   3
# 9       9  10   1  A  52612  507H7173  96040545  1   5.0  370.0  ...   4
# 10     10  11  12  A  52612  507H7173  96040545  2  21.2   31.0  ...   1
# 11     11  12   1  A  52612  507H7173  96040545  2  15.2   63.0  ...   1
# 12     12  13   2  A  52612  507H7173  96040545  2  11.0   92.0  ...   1
# 13     13  14   1  A  52613    7H7763  94040425  1  21.5  192.0  ...   1
# 14     14  15   2  A  52613    7H7763  94040425  1  20.7  234.0  ...   1
# 15     15  16   3  A  52613    7H7763  94040425  1  18.7  255.0  ...   1
# 16     16  17   4  A  52613    7H7763  94040425  1  21.5  285.0  ...   1
# 17     17  18  12  A  52613    7H7763  94040425  1  19.0  159.0  ...   1
# 18     18  19  11  A  52613    7H7763  94040425  1  19.0  133.0  ...   1
# 19     19  20  10  A  52613    7H7763  94040425  1  19.5  103.0  ...   1
# 20     20  21   8  A  52613    7H7763  94040425  1   8.0   61.0  ...   0
# 21     21  22   7  A  52613    7H7763  94040425  1  18.5   32.0  ...   0
# 22     22  23   7  A  52613    7H7763  94040425  2  30.4    8.0  ...   0
# 23     23  24   8  A  52613    7H7763  94040425  2  36.2   41.0  ...   0
# 24     24  25   9  A  52613    7H7763  94040425  2  32.8   76.0  ...   0
#
#           21 season  cycle  times  sub  year  cycle2  health  weight
# 0   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 1   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 2   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 3   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 4   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 5   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 6   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 7   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 8   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 9   501H8784    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 10   14H6080    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 11   14H6080    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 12   14H6080    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 13    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 14    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 15    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 16    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 17    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 18    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 19    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 20    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 21    7H9346    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 22   7H10272    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 23   7H10272    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 24   7H10272    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
#
# [25 rows x 21 columns]

# %%
new_test.head(25)
# Out:
#     index     1  3  4      5         6         7  9  11     10  ...  18  \
# 0     479   480  1  A  52631  501H9952  97040152  4 NaN  435.0  ...   6
# 1     741   742  2  A  52640  501H9952  96040567  4 NaN   13.0  ...   0
# 2     742   743  3  A  52640  501H9952  96040567  4 NaN   35.0  ...   1
# 3     743   744  4  A  52640  501H9952  96040567  4 NaN   70.0  ...   1
# 4     744   745  5  A  52640  501H9952  96040567  4 NaN   98.0  ...   1
# 5     792   793  2  A  52641  614H5010  97040119  6 NaN  279.0  ...   1
# 6     793   794  1  A  52641  614H5010  97040119  6 NaN  247.0  ...   1
# 7     799   800  5  A  52641  614H5010  97040119  7 NaN   12.0  ...   0
# 8     800   801  6  A  52641  614H5010  97040119  7 NaN   39.0  ...   0
# 9     801   802  7  A  52641  614H5010  97040119  7 NaN   67.0  ...   0
# 10    947   948  5  A  52648    7H7735  97040166  5 NaN  254.0  ...   1
# 11    948   949  4  A  52648    7H7735  97040166  5 NaN  226.0  ...   1
# 12    953   954  1  A  52648    7H7735  97040166  5 NaN  137.0  ...   1
# 13    954   955  2  A  52648    7H7735  97040166  5 NaN  169.0  ...   1
# 14    955   956  3  A  52648    7H7735  97040166  5 NaN  191.0  ...   1
# 15   1511  1512  2  A  52678   11H8035  94040423  3 NaN  510.0  ...   6
# 16   1512  1513  1  A  52678   11H8035  94040423  3 NaN  478.0  ...   6
# 17   1551  1552  1  A  52679   7H10427  95040492  4 NaN  157.0  ...   0
# 18   1552  1553  2  A  52679   7H10427  95040492  4 NaN  189.0  ...   0
# 19   1553  1554  3  A  52679   7H10427  95040492  4 NaN  211.0  ...   1
# 20   1557  1558  4  A  52679   7H10427  95040492  4 NaN  246.0  ...   1
# 21   1558  1559  5  A  52679   7H10427  95040492  4 NaN  274.0  ...   1
# 22   1559  1560  7  A  52679   7H10427  95040492  4 NaN  329.0  ...   1
# 23   1560  1561  6  A  52679   7H10427  95040492  4 NaN  301.0  ...   1
# 24   1636  1637  3  A  52681  507H8747  97040147  3 NaN  224.0  ...   3
#
#             21 season  cycle  times  sub  year  cycle2  health  weight
# 0   614HO07276    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 1   551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 2   551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 3   551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 4   551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 5   507HO12236    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 6   507HO12236    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 7          NaN    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 8          NaN    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 9          NaN    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 10  551HO00687    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 11  551HO00687    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 12  551HO00687    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 13  551HO00687    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 14  551HO00687    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 15  614HO07276    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 16  614HO07276    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 17  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 18  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 19  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 20  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 21  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 22  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 23  551HO00695    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
# 24  509HO12026    NaN    NaN    NaN  NaN   NaN     NaN     NaN     NaN
#
# [25 rows x 21 columns]

# %%
#train有不需要判斷的編號就去掉
for i in range(len(new_test['5'])):
    if len(new_train.index[new_train['5'] == new_test['5'][i]]) == 0:
        new_train=new_train.drop([i])
new_train.reset_index(inplace=True)
for i in range(len(new_train['11'])):
    if new_train['11'][i] == 0:
        new_train = new_train.drop([i])
#new_train.reset_index(inplace=True)
new_train
# Out:
#        level_0  index      1  3  4         5         6            7  9    11  \
# 0            0      0      1  3  A     52612  507H7173     96040545  1  29.4
# 1            1      1      2  4  A     52612  507H7173     96040545  1  27.8
# 2            2      2      3  5  A     52612  507H7173     96040545  1   9.0
# 3            3      3      4  6  A     52612  507H7173     96040545  1  13.0
# 4            4      4      5  7  A     52612  507H7173     96040545  1  13.2
# ...        ...    ...    ... .. ..       ...       ...          ... ..   ...
# 32557    33249  37512  37513  1  C  93184912   14H1999  8.51715e+07  8  20.0
# 32558    33250  37513  37514  5  C  93184912   14H1999  8.51715e+07  8  21.0
# 32559    33251  37514  37515  6  C  93184912   14H1999  8.51715e+07  8  19.0
# 32560    33252  37515  37516  7  C  93184912   14H1999  8.51715e+07  8  12.0
# 32561    33253  37516  37517  8  C  93184912   14H1999  8.51715e+07  8  10.0
#
#        ...  18        21  season cycle  times  sub  year  cycle2  health  \
# 0      ...   1  501H8784     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 1      ...   1  501H8784     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 2      ...   2  501H8784     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 3      ...   2  501H8784     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 4      ...   2  501H8784     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# ...    ...  ..       ...     ...   ...    ...  ...   ...     ...     ...
# 32557  ...   0       NaN     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 32558  ...   0       NaN     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 32559  ...   0       NaN     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 32560  ...   0       NaN     NaN   NaN    NaN  NaN   NaN     NaN     NaN
# 32561  ...   0       NaN     NaN   NaN    NaN  NaN   NaN     NaN     NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 32557     NaN
# 32558     NaN
# 32559     NaN
# 32560     NaN
# 32561     NaN
#
# [32495 rows x 22 columns]

# %%
new_train['6']=new_train['6'].fillna("NoData").astype("str")
new_test['6']=new_test['6'].fillna("NoData").astype("str")
new_train['7']=new_train['7'].fillna("NoData").astype("str")
new_test['7']=new_test['7'].fillna("NoData").astype("str")
new_train['21']=new_train['21'].fillna("NoData").astype("str")
new_test['21']=new_test['21'].fillna("NoData").astype("str")
avg_weight = birth['6'].mean()
birth['6'] = birth['6'].fillna(birth['6'].mean())

new_train.dropna(subset=['10','6','7'], inplace=True)

new_train['year']=report['2']
new_test['year']=test['2']

# %%
new_train
# Out:
#        level_0  index      1  3  4         5         6           7  9    11  \
# 0            0      0      1  3  A     52612  507H7173    96040545  1  29.4
# 1            1      1      2  4  A     52612  507H7173    96040545  1  27.8
# 2            2      2      3  5  A     52612  507H7173    96040545  1   9.0
# 3            3      3      4  6  A     52612  507H7173    96040545  1  13.0
# 4            4      4      5  7  A     52612  507H7173    96040545  1  13.2
# ...        ...    ...    ... .. ..       ...       ...         ... ..   ...
# 32557    33249  37512  37513  1  C  93184912   14H1999  85171537.0  8  20.0
# 32558    33250  37513  37514  5  C  93184912   14H1999  85171537.0  8  21.0
# 32559    33251  37514  37515  6  C  93184912   14H1999  85171537.0  8  19.0
# 32560    33252  37515  37516  7  C  93184912   14H1999  85171537.0  8  12.0
# 32561    33253  37516  37517  8  C  93184912   14H1999  85171537.0  8  10.0
#
#        ...  18        21  season cycle  times  sub    year  cycle2  health  \
# 0      ...   1  501H8784     NaN   NaN    NaN  NaN  2013.0     NaN     NaN
# 1      ...   1  501H8784     NaN   NaN    NaN  NaN  2013.0     NaN     NaN
# 2      ...   2  501H8784     NaN   NaN    NaN  NaN  2013.0     NaN     NaN
# 3      ...   2  501H8784     NaN   NaN    NaN  NaN  2013.0     NaN     NaN
# 4      ...   2  501H8784     NaN   NaN    NaN  NaN  2013.0     NaN     NaN
# ...    ...  ..       ...     ...   ...    ...  ...     ...     ...     ...
# 32557  ...   0    NoData     NaN   NaN    NaN  NaN  2017.0     NaN     NaN
# 32558  ...   0    NoData     NaN   NaN    NaN  NaN  2015.0     NaN     NaN
# 32559  ...   0    NoData     NaN   NaN    NaN  NaN  2015.0     NaN     NaN
# 32560  ...   0    NoData     NaN   NaN    NaN  NaN  2015.0     NaN     NaN
# 32561  ...   0    NoData     NaN   NaN    NaN  NaN  2015.0     NaN     NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 32557     NaN
# 32558     NaN
# 32559     NaN
# 32560     NaN
# 32561     NaN
#
# [32494 rows x 22 columns]

# %%
#train對上疾病資料，當年當月有病就1，反之0
from datetime import datetime
for i in range(len(spec)):
    dd=datetime.strptime(spec['4'][i], "%Y/%m/%d %H:%M")
    if len(new_train.index[new_train['5'] == spec['1'][i]])>0:
        for j in new_train.index[new_train['5'] == spec['1'][i]]:
            if new_train['year'][j] == dd.year and new_train['3'][j] == dd.month and new_train['4'][j]==spec['7'][i]:
                new_train['health'][j] = 1
    if len(new_test.index[new_test['5'] == spec['1'][i]])>0:
        for j in new_test.index[new_test['5'] == spec['1'][i]]:
            if new_test['year'][j] == dd.year and new_test['3'][j] == dd.month and new_test['4'][j]==spec['7'][i]:
                new_test['health'][j] = 1
                
for i in range(len(birth)):
    if len(new_train.index[new_train['5'] == birth['1'][i]])>0:
        for j in new_train.index[new_train['5'] == birth['1'][i]]:
                new_train['weight'][j] = birth['6'][i]
    if len(new_test.index[new_test['5'] == birth['1'][i]])>0:
        for j in new_test.index[new_test['5'] == birth['1'][i]]:
                new_test['weight'][j] = birth['6'][i]
new_train['weight'] = new_train['weight'].fillna(avg_weight)
new_test['weight'] = new_test['weight'].fillna(avg_weight)
# Out:
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['health'][j] = 1
# <ipython-input-17-99bd5468cb04>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]
# <ipython-input-17-99bd5468cb04>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['weight'][j] = birth['6'][i]

# %%
new_train=new_train.fillna(0)
new_test=new_test.fillna(0)

# %%
new_train.reset_index(inplace=True,drop=True)

# %%
for i in range(len(new_train['3'])):
    if int(new_train['3'][i]) >=3 and int(new_train['3'][i])<=5:
        new_train['season'][i] = 0
    elif int(new_train['3'][i]) >=6 and int(new_train['3'][i])<=8:
        new_train['season'][i] = 1
    elif int(new_train['3'][i]) >=9 and int(new_train['3'][i])<=11:
        new_train['season'][i] = 2
    else:
        new_train['season'][i] = 3
    if int(new_train['10'][i]) <=100:
        new_train['cycle'][i] = 0
    elif int(new_train['10'][i]) >=101 and int(new_train['10'][i]) <=200 :
        new_train['cycle'][i] = 1
    elif int(new_train['10'][i]) >=201 and int(new_train['10'][i]) <=305:
        new_train['cycle'][i] = 2
    else:
        new_train['cycle'][i] = 3
    if int(new_train['9'][i]) <=2:
        new_train['times'][i] = 0
    elif int(new_train['9'][i]) >=7:
        new_train['times'][i] = 2
    else:
        new_train['times'][i] = 1
    new_train['sub'][i]=2019-int(new_train['year'][i])
for i in range(len(new_test['3'])):
    if int(new_test['3'][i]) >=3 and int(new_test['3'][i])<=5:
        new_test['season'][i] = 0
    elif int(new_test['3'][i]) >=6 and int(new_test['3'][i])<=8:
        new_test['season'][i] = 1
    elif int(new_test['3'][i]) >=9 and int(new_test['3'][i])<=11:
        new_test['season'][i] = 2
    else:
        new_test['season'][i] = 3
    if int(new_test['10'][i]) <=100:
        new_test['cycle'][i] = 0
    elif int(new_test['10'][i]) >=101 and int(new_test['10'][i]) <=200 :
        new_test['cycle'][i] = 1
    elif int(new_test['10'][i]) >=201 and int(new_test['10'][i]) <=305:
        new_test['cycle'][i] = 2
    else:
        new_test['cycle'][i] = 3
    if int(new_test['9'][i]) <=2:
        new_test['times'][i] = 0
    elif int(new_test['9'][i]) >=7:
        new_test['times'][i] = 2
    else:
        new_test['times'][i] = 1
    new_test['sub'][i]=2019-int(new_test['year'][i])
new_train
new_test
# Out:
# <ipython-input-20-96cb5ee3b600>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['season'][i] = 0
# <ipython-input-20-96cb5ee3b600>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['cycle'][i] = 0
# <ipython-input-20-96cb5ee3b600>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['times'][i] = 0
# <ipython-input-20-96cb5ee3b600>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['sub'][i]=2019-int(new_train['year'][i])
# <ipython-input-20-96cb5ee3b600>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['cycle'][i] = 1
# <ipython-input-20-96cb5ee3b600>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['season'][i] = 1
# <ipython-input-20-96cb5ee3b600>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['cycle'][i] = 2
# <ipython-input-20-96cb5ee3b600>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['season'][i] = 2
# <ipython-input-20-96cb5ee3b600>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['cycle'][i] = 3
# <ipython-input-20-96cb5ee3b600>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['season'][i] = 3
# <ipython-input-20-96cb5ee3b600>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['times'][i] = 1
# <ipython-input-20-96cb5ee3b600>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_train['times'][i] = 2
# <ipython-input-20-96cb5ee3b600>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['season'][i] = 3
# <ipython-input-20-96cb5ee3b600>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['cycle'][i] = 3
# <ipython-input-20-96cb5ee3b600>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['times'][i] = 1
# <ipython-input-20-96cb5ee3b600>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['sub'][i]=2019-int(new_test['year'][i])
# <ipython-input-20-96cb5ee3b600>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['cycle'][i] = 0
# <ipython-input-20-96cb5ee3b600>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['season'][i] = 0
# <ipython-input-20-96cb5ee3b600>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['cycle'][i] = 2
# <ipython-input-20-96cb5ee3b600>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['times'][i] = 2
# <ipython-input-20-96cb5ee3b600>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['season'][i] = 1
# <ipython-input-20-96cb5ee3b600>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['cycle'][i] = 1
# <ipython-input-20-96cb5ee3b600>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_test['times'][i] = 0
#       index      1  3  4        5           6          7  9   11     10  ...  \
# 0       479    480  1  A    52631    501H9952   97040152  4  0.0  435.0  ...
# 1       741    742  2  A    52640    501H9952   96040567  4  0.0   13.0  ...
# 2       742    743  3  A    52640    501H9952   96040567  4  0.0   35.0  ...
# 3       743    744  4  A    52640    501H9952   96040567  4  0.0   70.0  ...
# 4       744    745  5  A    52640    501H9952   96040567  4  0.0   98.0  ...
# ...     ...    ... .. ..      ...         ...        ... ..  ...    ...  ...
# 4258  37480  37481  6  C  6187446  001HO11511  4170458.0  1  0.0   15.0  ...
# 4259  37481  37482  6  C  6187448  001HO11511  3172306.0  1  0.0   22.0  ...
# 4260  37482  37483  6  C  6187449  001HO11511  2176835.0  1  0.0   21.0  ...
# 4261  37483  37484  7  C  6187449  001HO11511  2176835.0  1  0.0   51.0  ...
# 4262  37484  37485  7  C  6187451  001HO11511  2176823.0  1  0.0   15.0  ...
#
#       18          21 season  cycle  times     sub  year  cycle2  health  \
# 0      6  614HO07276    3.0    3.0    1.0  2019.0   0.0     0.0     0.0
# 1      0  551HO00695    3.0    0.0    1.0  2019.0   0.0     0.0     0.0
# 2      1  551HO00695    0.0    0.0    1.0  2019.0   0.0     0.0     0.0
# 3      1  551HO00695    0.0    0.0    1.0  2019.0   0.0     0.0     0.0
# 4      1  551HO00695    0.0    0.0    1.0  2019.0   0.0     0.0     0.0
# ...   ..         ...    ...    ...    ...     ...   ...     ...     ...
# 4258   0  001HO12901    1.0    0.0    0.0  2019.0   0.0     0.0     0.0
# 4259   0      NoData    1.0    0.0    0.0  2019.0   0.0     0.0     0.0
# 4260   0      NoData    1.0    0.0    0.0  2019.0   0.0     0.0     0.0
# 4261   0      NoData    1.0    0.0    0.0  2019.0   0.0     0.0     0.0
# 4262   0      NoData    1.0    0.0    0.0  2019.0   0.0     0.0     0.0
#
#           weight
# 0     576.584507
# 1     576.584507
# 2     576.584507
# 3     576.584507
# 4     576.584507
# ...          ...
# 4258  540.000000
# 4259  490.000000
# 4260  540.000000
# 4261  540.000000
# 4262  505.000000
#
# [4263 rows x 21 columns]

# %%
farm_mapping = {"A":0,"B":1,"C":2}
new_train['4'] = new_train["4"].map(farm_mapping)
new_test['4'] = new_test["4"].map(farm_mapping)

# %%
new_train=new_train.fillna(0)
new_test=new_test.fillna(0)

# %%
new_train_backup = new_train
new_test_backup = new_test

# %%
ttrain=pd.DataFrame(data=new_train_backup,columns=['1','4','9','10','11','14','18','health','season','weight','times'])
ttest=pd.DataFrame(data=new_test_backup,columns=['1','4','9','10','11','14','18','health','season','weight','times'])

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from math import sqrt
from xgboost.sklearn import XGBRegressor as xgbr
from sklearn.model_selection import GridSearchCV
def final_prep(data, test):
    Y = data[ "11" ]
    Y_test = test[ "11" ]
    P_ID = test["1"]
    data_N = data.drop([ '1', '11'], axis=1)
    test_N = test.drop(['1', '11'], axis=1)
    return data_N, Y, test_N, Y_test, P_ID
def build_model(x, y, grid):
    predictor = xgbr()
    if grid: # if Ture, run Grid Search
        xgb1 = XGBRegressor()
        parameters = {'nthread': 4, 'objective':'reg:squarederror',
        'learning_rate':[.03, .05, .07], 'max_depth':[5, 6, 7],
        'min_child_weight':[4], 'silent':[1], 'subsample':[0.7],
        'colsample_bytree':[0.7], 'n_estimators':[500]}
        # replace predictor by gridSearch
        predictor = GridSearchCV(xgbl, parameters, cv = 2, n_jobs = 5, verbose=True)
    gbr_model = predictor.fit(x, y)
    return gbr_model

# %%
def prediction(model, x_val, y_val, ID_val, grid):
    prediction = model.predict(x_val)
    if grid: #if set True
        print( "Best_score_" , model.best_score_)
        print( "Best_params ", model.best_params_)
    results = pd.DataFrame(columns=[ 'ID', '1'])
    sqrE = 0
    for i in range(len(x_val)):
        results.loc[i] = [ID_val[i], prediction[i]]
        sqrE += (prediction[i] - y_val[i])**2
    rmse = sqrt( sqrE / len(x_val))
    return rmse, results
                                    
def submit(Ta, Va, grid):
    train_X, train_Y, val_X, val_Y, val_ID = final_prep(Ta, Va)
    model_prediction = build_model(train_X, train_Y, grid)
    perf, pred = prediction(model_prediction, val_X, val_Y, val_ID, grid)
    return perf, pred
                                    
grid = False # if True, use defualt hyper-parameters for xgb
for k in range(11): # loop over all 11 prodictors for individual submissions
    Ta = ttrain
    Va = ttest
    #Ta = read_csv("TA.csv", sep=',', header=0)
    #Va = read_csv("VA.csv", sep=',', header=0)
    performance, predictions = submit(Ta, Va, grid)
    #ttrain.to_csv('TA.csv',index=False)
    predictions.to_csv('predictions.csv', sep=',',header=1)
    print ( 'RMSE_', str(k+1), ' is ' , performance)
# Out:
# RMSE_ 1  is  25.9185096497156
# RMSE_ 2  is  25.9185096497156
# RMSE_ 3  is  25.9185096497156
# RMSE_ 4  is  25.9185096497156
# RMSE_ 5  is  25.9185096497156
# RMSE_ 6  is  25.9185096497156
# RMSE_ 7  is  25.9185096497156
# RMSE_ 8  is  25.9185096497156
# RMSE_ 9  is  25.9185096497156
# RMSE_ 10  is  25.9185096497156
# RMSE_ 11  is  25.9185096497156
